# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %%
ax1 = plt.axes()#creer un axe standard
ax2 = plt.axes([0.2, 0.65, 0.2, 0.2])#position ainis que la taille

# %%
for i in range(1, 5):
    plt.subplot(2, 2, i)#nb de ligne nb de colonnes nb index
    plt.text(0.5, 0.5, str(("Client",i)),fontsize=18, ha='center')

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)#creaion des differentes grilles 
plt.subplot(grid[0, :2])
plt.subplot(grid[0, 2:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection='3d')

# %%
z = np.linspace(0, 1 ,100)#variables conteant 100 val entre 0et1

# %%
x = z * np.sin(20 * z)
y = z * np.cos(20 *z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(x, y, z, 'b') #sens-+b
